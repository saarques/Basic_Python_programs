# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# import seaborn as sns
# %matplotlib inline
from urllib.request import urlopen
from bs4 import BeautifulSoup

# %%
url='https://timesofindia.indiatimes.com/'
html=urlopen(url)

# %%
soup=BeautifulSoup(html, 'lxml')
type(soup)
# Out:
# bs4.BeautifulSoup

# %%
title=soup.title
print(title)
# Out:
# <title>News, Breaking News, National news, Latest Bollywood News, Sports News, Business News &amp; Political News | Times of India</title>

# %%
text=soup.get_text
# print(text)

# %%
links=soup.find_all('a')
raw_data=[]
for i in links:
    raw_data.append(i.get('href'))
type(raw_data)
# raw_data
# import re

# list_rows = []
# for row in links:
#     cells = row.find_all('href')
#     str_cells = str(cells)
#     clean = re.compile('<.*?>')
#     clean2 = (re.sub(clean, '',str_cells))
#     list_rows.append(clean2)
# print(clean2)
# print(links[:10])
# type(clean2)
# Out:
# list

# %%
# raw_data= ''.join(raw_data)
raw_data=str(raw_data)
clean_text=BeautifulSoup(raw_data, 'lxml').get_text()
# clean_text
type(raw_data)
# Out:
# str

# %%
entertainment={'bollywood':0, 'hollywood':0, 'actor':0, 'actress':0, 'movie':0, 'songs':0}
sports={'cricket':0, 'football':0, 'dhoni':0, 'virat kohli':0, 'sachin tendulkar':0, 'odi':0, 'score':0}
crime={'kill':0, 'death':0, 'rape':0, 'assault':0, 'loot':0, 'dowry':0}
politics={'election':0, 'defamation':0, 'bill':0, 'allegations':0, 'campaign':0}
category=[entertainment, sports, crime, politics]
sundup={"india":0, "sport":0}
for key, value in sundup.items():
    if key in raw_data:
        value +=1
sundup
# Out:
# {'india': 0, 'sport': 0}

# %%
# clean_text=list(clean_text)
clean_text
# dictionary of keywords
# Out:
# "['https://jsso.indiatimes.com/sso/identity/profile/edit?channel=toi', 'http://mytimes.indiatimes.com/?channel=toi', 'https://www.timespoints.com/#/products?utm_source=TOI&utm_medium=Header_Dropdown&utm_campaign=TOI_HeaderDropdown', '#0', 'https://twitter.com/timesofindia', 'https://www.facebook.com/TimesofIndia', 'https://plus.google.com/117150671992820587865?prsrc=3', 'https://timesofindia.indiatimes.com/rss.cms', 'https://www.youtube.com/user/TimesOfIndiaChannel', 'javascript:void(0);', '/', '/', '/videos', '/top-videos', '/trending-videos', '/videos/city', '/videos/news', '/videos/entertainment', '/videos/beautypageants', '/videos/sports', '/videos/tv', '/videos/lifestyle', '/videos/lifestyle/health-tips-videos', '/videos/filmfare', '/humour/videos/videolist/57448618.cms', '/videos/business', '/videos/tech', '/videos/auto', '/videos/entertainment/music', '/videos/entertainment/events/mumbai', 'https://navbharattimes.indiatimes.com/video/videolist/4901865.cms', '/city', '/city/mum
# ...
